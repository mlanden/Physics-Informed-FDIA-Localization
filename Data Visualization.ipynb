# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import yaml

# %%
conf_path = "configs/swat.yaml"
with open(conf_path, "r") as fd:
    conf = yaml.safe_load(fd)
normal = pd.read_csv(conf["data"]["normal"], skiprows=0, header=1)
attack = pd.read_csv(conf["data"]["attack"], skiprows=0, header=1)
attack.head()
# Out:
#     28/12/2015 10:00:00 AM  2.427057  522.8467  2  2.1  1  262.0161  8.396437  \
# 0   28/12/2015 10:00:01 AM  2.446274  522.8860  2    2  1  262.0161  8.396437
# 1   28/12/2015 10:00:02 AM  2.489191  522.8467  2    2  1  262.0161  8.394514
# 2   28/12/2015 10:00:03 AM  2.534350  522.9645  2    2  1  262.0161  8.394514
# 3   28/12/2015 10:00:04 AM  2.569260  523.4748  2    2  1  262.0161  8.394514
# 4   28/12/2015 10:00:05 AM  2.609294  523.8673  2    2  1  262.0161  8.394514
#
#    328.6337  2.445391  ...  2.9  1.12  250.8652  1.649953  189.5988  \
# 0  328.6337  2.445391  ...    2     1  250.8652  1.649953  189.6789
# 1  328.6337  2.442316  ...    2     1  250.8812  1.649953  189.6789
# 2  328.6337  2.442316  ...    2     1  250.8812  1.649953  189.6148
# 3  328.6337  2.443085  ...    2     1  250.8812  1.649953  189.5027
# 4  328.6337  2.444110  ...    2     1  250.7530  1.649953  189.5027
#
#    0.000128152  1.13  1.14  1.15  Normal
# 0     0.000128     1     1     1  Normal
# ...

# %%
i = 24
start = 80000
x = np.arange(len(normal) - start)
plt.plot(x, normal.iloc[start:, i])
plt.show()

# %%
i = 0
norm = np.ma.masked_where(attack.iloc[:,-1] == "Normal", attack.iloc[:, i])
attck = np.ma.masked_where(attack.iloc[:,-1] == "Attack", attack.iloc[:, i])
plt.plot(attack.iloc[:, i], norm)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 5
#       3 attck = np.ma.masked_where(attack.iloc[:,-1] == "Attack", attack.iloc[:, i])
#       4 plt.plot(attack.iloc[:, i], norm)
# ----> 5 plt.show()
#
# File ~\ICS-Attack-Detection\venv\lib\site-packages\matplotlib\pyplot.py:421, in show(*args, **kwargs)
#     377 """
#     378 Display all open figures.
#     379
#    (...)
#     418 explicitly there.
#     419 """
#     420 _warn_if_gui_out_of_main_thread()
# --> 421 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\ICS-Attack-Detection\venv\lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
# ...
